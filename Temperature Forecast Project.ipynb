# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.head(10)
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
# 5      6.0  30-06-2013          31.9          23.5    52.437126    85.307251
# 6      7.0  30-06-2013          31.4          24.4    56.287189    81.019760
# 7      8.0  30-06-2013          32.1          23.6    52.326218    78.004539
# 8      9.0  30-06-2013          31.4          22.0    55.338791    80.784607
# 9     10.0  30-06-2013          31.6          20.5    56.651203    86.849632
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# ...

# %% [markdown]
# Attribute Information:
#
#
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# their are total 7752 rows and 25 columns in the dataset.

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# We are having aal the columns with Float data type, except Date, we will break this column into subcolumns in next step.

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df["Year"]=df['Date'].dt.year
df["Month"]=df['Date'].dt.month
df["day"]=df["Date"].dt.day

# %%
df.head()
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0 2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0 2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...      lat  \
# 0         28.074101         23.006936  6.818887   69.451805  ...  37.6046
# 1         29.850689         24.035009  5.691890   51.937448  ...  37.6046
# 2         30.091292         24.565633  6.138224   20.573050  ...  37.5776
# 3         29.704629         23.326177  5.650050   65.727144  ...  37.6450
# 4         29.113934         23.486480  5.735004  107.965535  ...  37.5507
#
# ...

# %% [markdown]
# We can drop the date column as we already converted the data from date column.

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.shape
# Out:
# (7752, 27)

# %% [markdown]
# So, now we have 7752 rows and 27 columns in the dataset and we will proceed with this.

# %%
df.dtypes
# Out:
# station             float64
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# Year                float64
# Month               float64
# day                 float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# station              2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# Year                 2
# Month                2
# day                  2
# dtype: int64

# %% [markdown]
# Thier are missing values in maximum columns.

# %%
df=df.replace(np.nan,df.mean())

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Year                0
# Month               0
# day                 0
# dtype: int64

# %% [markdown]
# Their are no mising values in the dataset now.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['Present_Tmax'],df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Next_Tmax'>

# %% [markdown]
# Thier is linear relationship between two columns.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['Present_Tmax'],df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Next_Tmin'>

# %% [markdown]
# As Present_Tmax increases, Next_Tmin is also increasing.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['Present_Tmin'],df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Next_Tmax'>

# %% [markdown]
# Their is linear relationship between the two columns.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['Present_Tmin'],df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Next_Tmin'>

# %% [markdown]
# The relation between two columns is linear.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_RHmin'],df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Next_Tmax'>

# %% [markdown]
# As humidity increases, temperature for next day is decraesing.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_RHmin'],df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Next_Tmin'>

# %% [markdown]
# As humidity is high, minimum temperature is also increasing.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_RHmax'],df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Next_Tmax'>

# %% [markdown]
# Maximum the humidity, Next_Tmax also decreasing.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_RHmax'],df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Next_Tmin'>

# %% [markdown]
# We are getting mix responses as sometimes Tmin is increasing and decreasing as per the maximum humidity on a perticular day.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_WS'],df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmax'>

# %% [markdown]
# As average wind speed for the day is increasing, maximum temperature is decreasing.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_WS'],df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmin'>

# %% [markdown]
# As average wind speed is increasing, minimum temperature of perticular day is increasing in some cases and decreasing in some cases.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_LH'],df['Next_Tmax'])
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmax'>

# %% [markdown]
# As average heat flux is high, temperature is also high.

# %%
plt.figure(figsize=[12,6])
sns.scatterplot(df['LDAPS_LH'],df['Next_Tmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmin'>

# %% [markdown]
# downing and increasing trend is found over here.

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['LDAPS_CC1'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC1'>

# %% [markdown]
# For 1st 6-hour, the highest range for the split average cloud cover is between 0.1 to 0.35(10% to 35%)

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['LDAPS_CC2'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC2'>

# %% [markdown]
# For second 6-hour, the highest range for the split average cloud cover is between 0.1 to 0.38(10% to 38%).

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['LDAPS_CC3'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC3'>

# %% [markdown]
# For third 6-hour, the highest range for the split average cloud cover is between 0.04 to 0.1(4% to 10%).

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['LDAPS_CC4'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4'>

# %% [markdown]
# For Fourth 6-hour, the highest range for the split average cloud cover is between 0.02 to 0.05(2% to 5%).

# %% [markdown]
# For first 12 hours, the split average cloud cover is in the range of 10% to 40% as highest and for next 12 hours the range is between 2% to 4% as highest.

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.210637      2.956557      2.403036    14.596973     7.157124
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.046162    84.316923
# 50%      13.000000     29.900000     23.400000    55.313244    89.699505
# 75%      19.000000     32.000000     24.900000    67.038254    93.704500
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.932898          2.333973     2.173245    33.567001
# ...

# %% [markdown]
# Above is the statistical summary of dataset which gives us following parameters for every column.
#
# Mean()
# Median()
# Standard deviation
# Min()
# Max()

# %% [markdown]
# Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000e+00      0.112655      0.131646    -0.066733
# Present_Tmax      1.126554e-01      1.000000      0.618760    -0.204571
# Present_Tmin      1.316462e-01      0.618760      1.000000     0.123143
# LDAPS_RHmin      -6.673316e-02     -0.204571      0.123143     1.000000
# LDAPS_RHmax      -1.669845e-01     -0.301787     -0.015140     0.579141
# LDAPS_Tmax_lapse  6.910718e-02      0.570129      0.464151    -0.564580
# LDAPS_Tmin_lapse  1.047582e-01      0.623496      0.762993     0.089476
# LDAPS_WS          5.277000e-03     -0.121820     -0.034675     0.294361
# LDAPS_LH         -1.333566e-01      0.135463     -0.009258    -0.070858
# LDAPS_CC1         6.918787e-03     -0.311805      0.084447     0.613818
# LDAPS_CC2         3.396039e-03     -0.213791      0.090263     0.745443
# LDAPS_CC3         6.940187e-04     -0.144018     -0.002772     0.689679
# ...

# %%
plt.figure(figsize=[20,8])
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Abve is the representation of correlation of columns of the dataset.

# %%
corr_matrix_1=df.corr()
corr_matrix_1['Next_Tmax'].sort_values(ascending=False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.827189
# Next_Tmin           0.621427
# Present_Tmax        0.610348
# LDAPS_Tmin_lapse    0.586983
# Present_Tmin        0.471806
# LDAPS_LH            0.157616
# station             0.107983
# Year                0.059995
# Solar radiation     0.008795
# lon                 0.003052
# Month              -0.026822
# lat                -0.053510
# Slope              -0.102725
# day                -0.116716
# LDAPS_PPT1         -0.118817
# DEM                -0.172538
# LDAPS_PPT2         -0.178383
# LDAPS_PPT4         -0.178718
# LDAPS_PPT3         -0.194143
# LDAPS_RHmax        -0.283738
# LDAPS_WS           -0.342729
# LDAPS_RHmin        -0.437898
# LDAPS_CC4          -0.446319
# LDAPS_CC1          -0.452541
# LDAPS_CC2          -0.490756
# LDAPS_CC3          -0.514680
# Name: Next_Tmax, dtype: float64

# %% [markdown]
# Highest Correlation with 'Next_Tmax'  - 'LDAPS_Tmax_lapse '(0.8271)
#
#
# Lowest Correlation with 'Next_Tmax'   -   'LDAPS'(-0.5146)

# %%
corr_matrix_2=df.corr()
corr_matrix_2['Next_Tmin'].sort_values(ascending=False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.880176
# Present_Tmin        0.796670
# Present_Tmax        0.622741
# Next_Tmax           0.621427
# LDAPS_Tmax_lapse    0.586868
# station             0.128293
# Solar radiation     0.120212
# LDAPS_RHmin         0.095019
# LDAPS_CC2           0.031250
# Year                0.023136
# LDAPS_PPT1          0.021323
# LDAPS_PPT2         -0.008058
# LDAPS_CC1          -0.011028
# Month              -0.024423
# lon                -0.046603
# LDAPS_CC3          -0.054726
# LDAPS_LH           -0.055440
# LDAPS_PPT3         -0.062622
# LDAPS_RHmax        -0.071997
# lat                -0.083533
# LDAPS_CC4          -0.085093
# LDAPS_WS           -0.096576
# LDAPS_PPT4         -0.103682
# day                -0.129339
# Slope              -0.146882
# DEM                -0.246906
# Name: Next_Tmin, dtype: float64

# %% [markdown]
# Highest Correlation with 'Next_Tmin' - 'LDAPS_Tmin_lapse '(0.8801)
#
# Lowest Correlation with 'Next_Tmin' - 'DEM'(-0.2469)

# %% [markdown]
# As in above dataset, we have two target column, so in every step we are doing all the necessary operations as compare to both.

# %%
plt.figure(figsize=[14,6])
plt.hist(df['lat'],bins=20)
plt.show()

# %%
Highest no. of frequency ranges for the column 'lat'(Lattitude) is between two ranges, 37.5 to 37.515 and 37.550 to 37.580.

# %%
plt.figure(figsize=[14,6])
plt.hist(df['lon'],bins=10)
plt.show()

# %% [markdown]
# Highest number of longitude is between the range of 127.02 to 127.05 i.e.,1550 times.

# %%
plt.figure(figsize=[14,6])
plt.hist(df['DEM'])
plt.show()

# %% [markdown]
# Highest number of Elevation is between the range of 10 to 30 i.e.,2800 times.

# %% [markdown]
# Plotting Boxplot to check outliers.

# %%
df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'day'],
#       dtype='object')

# %%
df.iloc[:,0:13].boxplot(figsize=[20,6])
plt.subplots_adjust(bottom=.25)
plt.show()

# %%
df['LDAPS_CC1'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Their are outliers in following columns:
#
#     Present_Tmax,Present_Tmin,LDAPS_RHmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse,LDAPS_WS,LDAPS_LH

# %%
df.iloc[:,13:].boxplot(figsize=[20,6])
plt.subplots_adjust
plt.show()

# %% [markdown]
# We are not getting proper insight here, we will check it one by one.

# %%
df['LDAPS_PPT1'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present .

# %%
df['LDAPS_PPT2'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_PPT3'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_PPT4'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in above four plots.

# %%
df['DEM'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in DEm column.

# %% [markdown]
# Outliers Removal Process

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
threshold=3
print(np.where(z>3))
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64), array([ 7, 14, 14, ..., 14, 15, 16], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    78.261383
# 7746     22.0          22.5          17.4    30.094858    83.690018
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936  6.818887   69.451805   0.233947
# ...

# %%
df.shape
# Out:
# (7752, 27)

# %%
df_new.shape
# Out:
# (6894, 27)

# %%
(6894/7752)*100
# Out:
# 88.93188854489165

# %% [markdown]
# So, here dataloss is more than 8%, we can not proceed with zscore technique, we will proceed with IQR for outliers.

# %%
df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'day'],
#       dtype='object')

# %%
sns.distplot(df['Present_Tmax'])
# Out:
# <AxesSubplot:xlabel='Present_Tmax', ylabel='Density'>

# %%
df['Present_Tmax'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data is normally distributed and the outliers are very near to whiskers, we can proceed with the same.

# %%
sns.distplot(df['Present_Tmin'])
# Out:
# <AxesSubplot:xlabel='Present_Tmin', ylabel='Density'>

# %%
df['Present_Tmin'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data is normally distributed.

# %%
upper_boundary=df['Present_Tmin'].mean()+3*df['Present_Tmin'].std()
lower_boundary=df['Present_Tmin'].mean()-3*df['Present_Tmin'].std()

# %%
print(upper_boundary)
print(lower_boundary)
# Out:
# 30.43416665963845
# 16.015950497352115

# %%
df['Present_Tmin'].describe()
# Out:
# count    7752.000000
# mean       23.225059
# std         2.403036
# min        11.300000
# 25%        21.700000
# 50%        23.400000
# 75%        24.900000
# max        29.900000
# Name: Present_Tmin, dtype: float64

# %% [markdown]
# We are going to proceed with the same data that is in column.

# %%
sns.distplot(df['LDAPS_RHmax'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Density'>

# %% [markdown]
# Data is left skewed.

# %%
IQR=df.LDAPS_RHmax.quantile(0.75)-df.LDAPS_RHmax.quantile(0.25)
IQR
# Out:
# 9.387577057499996

# %%
df['LDAPS_RHmax'].describe()
# Out:
# count    7752.000000
# mean       88.374804
# std         7.157124
# min        58.936283
# 25%        84.316923
# 50%        89.699505
# 75%        93.704500
# max       100.000153
# Name: LDAPS_RHmax, dtype: float64

# %%
lower_bridge=df['LDAPS_RHmax'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_RHmax'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# 56.15419196750001
# 121.86723136999998

# %% [markdown]
# We are going to use same data as available previouly for the column.

# %%
sns.distplot(df['LDAPS_RHmin'])
# Out:
# <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Density'>

# %%
df['LDAPS_RHmin'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data is normally distributed and no outliers are there.

# %%
sns.distplot(df['LDAPS_Tmax_lapse'])
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Density'>

# %%
df['LDAPS_Tmax_lapse'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data is normally distributed and some outliers are there.

# %%
upper_boundary=df['LDAPS_Tmax_lapse'].mean()+3*df['LDAPS_Tmax_lapse'].std()
lower_boundary=df['LDAPS_Tmax_lapse'].mean()-3*df['LDAPS_Tmax_lapse'].std()

# %%
print(upper_boundary)
print(lower_boundary)
# Out:
# 38.41213929107991
# 20.81475379454734

# %%
df['LDAPS_Tmax_lapse'].describe()
# Out:
# count    7752.000000
# mean       29.613447
# std         2.932898
# min        17.624954
# 25%        27.693091
# 50%        29.662273
# 75%        31.683819
# max        38.542255
# Name: LDAPS_Tmax_lapse, dtype: float64

# %% [markdown]
# We are going to continue with same data as available in LDAPS_Tmax_lapse column.

# %%
sns.distplot(df['LDAPS_Tmin_lapse'])
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Density'>

# %%
df['LDAPS_Tmin_lapse'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are there but very near to whisker, we will not remove tehm.

# %%
 df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'day'],
#       dtype='object')

# %%
sns.distplot(df['LDAPS_WS'])
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Density'>

# %%
sns.boxplot(df['LDAPS_WS'])
# Out:
# <AxesSubplot:xlabel='LDAPS_WS'>

# %% [markdown]
# data is not normally distributed due to presence of outliers.

# %%
IQR=df.LDAPS_WS.quantile(0.75)-df.LDAPS_WS.quantile(0.25)
IQR
# Out:
# 2.3209839067500004

# %%
lower_bridge=df['LDAPS_WS'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_WS'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -1.2764645050000016
# 14.970422842250002

# %%
df['LDAPS_WS'].describe()
# Out:
# count    7752.000000
# mean        7.097875
# std         2.173245
# min         2.882580
# 25%         5.686487
# 50%         6.563068
# 75%         8.007471
# max        21.857621
# Name: LDAPS_WS, dtype: float64

# %%
df.loc[df['LDAPS_WS']>=15,'LDAPS_WS']=15

# %%
sns.distplot(df['LDAPS_LH'])
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Density'>

# %% [markdown]
# Data is normally distributed.

# %%
upper_boundary=df['LDAPS_LH'].mean()+3*df['LDAPS_LH'].std()
lower_boundary=df['LDAPS_LH'].mean()-3*df['LDAPS_LH'].std()

# %%
print(upper_boundary)
print(lower_boundary)
# Out:
# 163.20602073815922
# -38.19598291947801

# %%
df['LDAPS_LH'].describe()
# Out:
# count    7752.000000
# mean       62.505019
# std        33.567001
# min       -13.603212
# 25%        37.532764
# 50%        57.310630
# 75%        83.904586
# max       213.414006
# Name: LDAPS_LH, dtype: float64

# %%
df.loc[df['LDAPS_LH']>=164,'LDAPS_LH']=164

# %%
sns.distplot(df['LDAPS_CC1'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Density'>

# %% [markdown]
# Data is slightly going down towards right due to presence of outliers.

# %%
IQR=df.LDAPS_CC1.quantile(0.75)-df.LDAPS_CC1.quantile(0.25)
IQR
# Out:
# 0.4233750357500001

# %%
lower_bridge=df['LDAPS_CC1'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['LDAPS_CC1'].quantile(0.75)+(IQR*1.5)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -0.4867411376250001
# 1.2067590053750001

# %%
df['LDAPS_CC1'].describe()
# Out:
# count    7752.000000
# mean        0.368774
# std         0.261185
# min         0.000000
# 25%         0.148321
# 50%         0.320110
# 75%         0.571696
# max         0.967277
# Name: LDAPS_CC1, dtype: float64

# %% [markdown]
# We are not going to remove any outliers as this will affect our model accuracy.

# %%
sns.distplot(df['LDAPS_CC2'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Density'>

# %%
IQR=df.LDAPS_CC2.quantile(0.75)-df.LDAPS_CC2.quantile(0.25)
IQR
# Out:
# 0.41263482575000004

# %%
lower_bridge=df['LDAPS_CC2'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_CC2'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -0.47662374987500006
# 1.173915553125

# %%
df['LDAPS_CC2'].describe()
# Out:
# count    7752.000000
# mean        0.356080
# std         0.256810
# min         0.000000
# 25%         0.142328
# 50%         0.315667
# 75%         0.554963
# max         0.968353
# Name: LDAPS_CC2, dtype: float64

# %% [markdown]
# No outlier removal needed.

# %%
sns.distplot(df['LDAPS_CC3'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Density'>

# %% [markdown]
# Data is right skewed.

# %%
IQR=df.LDAPS_CC3.quantile(0.75)-df.LDAPS_CC3.quantile(0.25)
IQR
# Out:
# 0.39090708575

# %%
lower_bridge=df['LDAPS_CC3'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_CC3'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -1.0696210925
# 1.66672850775

# %%
df['LDAPS_CC3'].describe()
# Out:
# count    7752.000000
# mean        0.318404
# std         0.249148
# min         0.000000
# 25%         0.103100
# 50%         0.265264
# 75%         0.494007
# max         0.983789
# Name: LDAPS_CC3, dtype: float64

# %%
df.loc[df['LDAPS_CC3']>=0.9,'LDAPS_CC3']=0.9

# %%
sns.distplot(df['LDAPS_CC4'])
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Density'>

# %% [markdown]
# Data is right skewed.

# %%
IQR=df.LDAPS_CC4.quantile(0.75)-df.LDAPS_CC4.quantile(0.25)
IQR
# Out:
# 0.41448949825000003

# %%
lower_bridge=df['LDAPS_CC4'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_CC4'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -1.16072769975
# 1.740698788

# %%
df['LDAPS_CC4'].describe()
# Out:
# count    7752.000000
# mean        0.299191
# std         0.253114
# min         0.000000
# 25%         0.082741
# 50%         0.232354
# 75%         0.497230
# max         0.974710
# Name: LDAPS_CC4, dtype: float64

# %%
df.loc[df['LDAPS_CC4']>=0.9,'LDAPS_CC4']=0.9

# %%
 df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'day'],
#       dtype='object')

# %%
sns.distplot(df['LDAPS_PPT1'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed.

# %%
IQR=df.LDAPS_PPT1.quantile(0.75)-df.LDAPS_PPT1.quantile(0.25)
IQR
# Out:
# 0.06759266775

# %%
lower_bridge=df['LDAPS_PPT1'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_PPT1'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -0.20277800325
# 0.270370671

# %%
df['LDAPS_PPT1'].describe()
# Out:
# count    7752.000000
# mean        0.591995
# std         1.936331
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.067593
# max        23.701544
# Name: LDAPS_PPT1, dtype: float64

# %%
df.loc[df['LDAPS_PPT1']>=0.28,'LDAPS_PPT1']=0.28

# %%
sns.distplot(df['LDAPS_PPT2'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Density'>

# %%
IQR=df.LDAPS_PPT2.quantile(0.75)-df.LDAPS_PPT2.quantile(0.25)
IQR
# Out:
# 0.024276131500000003

# %%
lower_bridge=df['LDAPS_PPT2'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_PPT2'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -0.0728283945
# 0.09710452600000001

# %%
df['LDAPS_PPT2'].describe()
# Out:
# count    7752.000000
# mean        0.485003
# std         1.754258
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.024276
# max        21.621661
# Name: LDAPS_PPT2, dtype: float64

# %%
df.loc[df['LDAPS_PPT2']>=0.097,'LDAPS_PPT2']=0.097

# %%
sns.distplot(df['LDAPS_PPT3'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Density'>

# %%
IQR=df.LDAPS_PPT3.quantile(0.75)-df.LDAPS_PPT3.quantile(0.25)
IQR
# Out:
# 0.0096971465

# %%
lower_bridge=df['LDAPS_PPT3'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_PPT3'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -0.0290914395
# 0.038788586

# %%
df.loc[df['LDAPS_PPT3']>=0.038,'LDAPS_PPT3']=0.038

# %%
sns.distplot(df['LDAPS_PPT4'])
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Density'>

# %%
IQR=df.LDAPS_PPT4.quantile(0.75)-df.LDAPS_PPT4.quantile(0.25)
IQR
# Out:
# 0.00069317775

# %%
lower_bridge=df['LDAPS_PPT4'].quantile(0.25)-(IQR*3)
upper_bridge=df['LDAPS_PPT4'].quantile(0.75)+(IQR*3)

# %%
print(lower_bridge)
print(upper_bridge)
# Out:
# -0.00207953325
# 0.002772711

# %%
df.loc[df['LDAPS_PPT4']>=0.038,'LDAPS_PPT4']=0.0027

# %%
df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'day'],
#       dtype='object')

# %%
sns.distplot(df['DEM'])
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='Density'>

# %%
upper_boundary=df['DEM'].mean()+3*df['DEM'].std()
lower_boundary=df['DEM'].mean()-3*df['DEM'].std()

# %%
print(upper_boundary)
print(lower_boundary)
# Out:
# 224.70731345683856
# -100.97136892639105

# %%
df['DEM'].describe()
# Out:
# count    7752.000000
# mean       61.867972
# std        54.279780
# min        12.370000
# 25%        28.700000
# 50%        45.716000
# 75%        59.832400
# max       212.335000
# Name: DEM, dtype: float64

# %% [markdown]
# WE will continue with the original values of column.

# %%
df['Slope'].plot.box()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['Slope'])
# Out:
# <AxesSubplot:xlabel='Slope', ylabel='Density'>

# %%
upper_boundary=df['Slope'].mean()+3*df['Slope'].std()
lower_boundary=df['Slope'].mean()-3*df['Slope'].std()

# %%
print(upper_boundary)
print(lower_boundary)
# Out:
# 5.368379010503743
# -2.8542820794923447

# %%
df['Slope'].describe()
# Out:
# count    7752.000000
# mean        1.257048
# std         1.370444
# min         0.098475
# 25%         0.271300
# 50%         0.618000
# 75%         1.767800
# max         5.178230
# Name: Slope, dtype: float64

# %% [markdown]
# so, we successfully removed outliers from the dataset.

# %%
df1=df.copy()

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750     13.0          20.0          11.3    19.794666    58.936283
# 7751     13.0          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
#spliting the dataset into x and y

x=df.drop(['Next_Tmax','Next_Tmin'],axis=1)
y=df.iloc[:,22:24]

# %%
df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Year', 'Month', 'day'],
#       dtype='object')

# %%
x
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750     13.0          20.0          11.3    19.794666    58.936283
# 7751     13.0          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
y
# Out:
#       Next_Tmax  Next_Tmin
# 0          29.1       21.2
# 1          30.5       22.5
# 2          31.1       23.9
# 3          31.7       24.3
# 4          31.2       22.5
# ...         ...        ...
# 7747       28.3       18.1
# 7748       28.6       18.8
# 7749       27.8       17.4
# 7750       17.4       11.3
# 7751       38.9       29.8
#
# [7752 rows x 2 columns]

# %% [markdown]
# Skewness Check

# %%
x.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.264137
# Present_Tmin       -0.367538
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.855015
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_WS            1.324214
# LDAPS_LH            0.628975
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3           0.620751
# LDAPS_CC4           0.657619
# LDAPS_PPT1          1.289818
# LDAPS_PPT2          1.260916
# LDAPS_PPT3          1.257618
# LDAPS_PPT4          5.396745
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Year                0.000000
# Month              -0.705332
# day                 0.245514
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
X_new=power_transform(x)
X_new=pd.DataFrame(X_new,columns=x.columns)

# %%
X_new.skew()
# Out:
# station            -0.204565
# Present_Tmax       -0.035006
# Present_Tmin       -0.012048
# LDAPS_RHmin        -0.017469
# LDAPS_RHmax        -0.115143
# LDAPS_Tmax_lapse   -0.009351
# LDAPS_Tmin_lapse   -0.017827
# LDAPS_WS            0.007554
# LDAPS_LH            0.048385
# LDAPS_CC1           0.046757
# LDAPS_CC2           0.045326
# LDAPS_CC3           0.086852
# LDAPS_CC4           0.126369
# LDAPS_PPT1          1.061086
# LDAPS_PPT2          1.082998
# LDAPS_PPT3          1.076986
# LDAPS_PPT4          1.255366
# lat                 0.000000
# lon                -0.198429
# DEM                 0.039456
# Slope               0.233968
# Solar radiation    -0.176636
# Year               -0.000215
# Month               0.043842
# day                -0.041879
# dtype: float64

# %% [markdown]
# Skewness is successfully removed.

# %%
from sklearn.preprocessing import StandardScaler

# %%
SC=StandardScaler()

# %%
X=SC.fit_transform(X_new)
X
# Out:
# array([[-1.86035552e+00, -4.08897262e-01, -7.97706579e-01, ...,
#         -1.41449849e+00, -5.82396754e-01,  1.41894798e+00],
#        [-1.64838475e+00,  7.05122710e-01, -7.20130385e-01, ...,
#         -1.41449849e+00, -5.82396754e-01,  1.41894798e+00],
#        [-1.45484830e+00,  5.95692407e-01, -2.76742340e-02, ...,
#         -1.41449849e+00, -5.82396754e-01,  1.41894798e+00],
#        ...,
#        [ 1.54118849e+00, -2.04992031e+00, -2.18006638e+00, ...,
#          1.41429358e+00,  3.64021961e-01,  1.41894798e+00],
#        [ 7.70875044e-02, -2.84618687e+00, -3.68800537e+00, ...,
#          1.02404287e-04, -8.76123533e-02,  2.06883325e-01],
#        [ 7.70875044e-02,  2.98103740e+00,  3.23307848e+00, ...,
#          1.02404287e-04, -8.76123533e-02,  2.06883325e-01]])

# %% [markdown]
# Data is scaled.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
#finding best random_state
maxr2_score=0
maxRs=0
for i in range(1,200):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=i)
    LR=LinearRegression()
    LR.fit(X_train,y_train)
    pred=LR.predict(X_test)
    r_2=r2_score(y_test,pred)
    if r_2>maxr2_score:
    
        maxr2_score=r_2
        maxRs=i
        
print("Best r2_score is", maxr2_score,"on Random state", maxRs)
# Out:
# Best r2_score is 0.8026594806019535 on Random state 89

# %%
#Lets Create new train_test_split with random state(89)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=89)

# %%
LR=LinearRegression()
LR.fit(X_train,y_train)
pred=LR.predict(X_test)
print(r2_score(y_test,pred))

print(mean_squared_error(y_test,pred))
print('Root mean squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.8026594806019535
# 1.623753310410156
# Root mean squared Error: 1.274265792686187

# %%
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
pred=dt.predict(X_test)
print(r2_score(y_test,pred))

print(mean_squared_error(y_test,pred))
print('Root mean squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.7764506134374838
# 1.7720360157918087
# Root mean squared Error: 1.331178431237454

# %%
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
pred=rf.predict(X_test)
print(r2_score(y_test,pred))

print(mean_squared_error(y_test,pred))
print('Root mean squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.9025120470260036
# 0.7745091280987612
# Root mean squared Error: 0.8800620024173076

# %% [markdown]
# We got different accuracies for different models, it may be due to Overfitting, we will check with cross validation.

# %%
#Linearregression
scr=cross_val_score(LinearRegression(),X,y,cv=5)
print(scr.mean())
# Out:
# 0.7118606138828223

# %%
#DecisionTreeRegressor
scr=cross_val_score(DecisionTreeRegressor(),X,y,cv=5)
print(scr.mean())
# Out:
# 0.4195425645514481

# %%
#RandomForestRegressor
scr=cross_val_score(RandomForestRegressor(),X,y,cv=5)
print(scr.mean())
# Out:
# 0.7058423313109389

# %% [markdown]
# The difference between the r2 score and cross val score for linear regression is less, we wiil do HYperParametertuning to it.

# %%
from sklearn.linear_model import Lasso,ElasticNet

# %%
ls=Lasso(alpha=0.0001)
ls.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
ls.coef_
# Out:
# array([[ 1.99292541e-01,  5.17052441e-01,  2.05684170e-01,
#          4.77159915e-01, -1.73565893e-02,  1.93148897e+00,
#          3.76317289e-02, -2.86945143e-01,  2.00268394e-01,
#         -2.17388411e-01, -1.40521811e-01, -1.97407800e-01,
#         -3.74661846e-01, -3.09327042e-02, -5.60844135e-02,
#          9.93625205e-03,  8.79355970e-02,  0.00000000e+00,
#         -1.35344834e-01,  5.00500001e-02, -5.76556425e-03,
#          7.18693928e-02,  9.78480173e-02, -6.97434197e-02,
#          8.79370823e-02],
#        [ 1.43018784e-02,  1.95495925e-01,  6.62332808e-01,
#          3.86136024e-01,  1.02831837e-01,  4.58379992e-01,
#          1.19539140e+00,  8.00585545e-02, -1.22318867e-02,
#         -9.99479228e-02,  1.33276866e-01,  1.68819046e-02,
#         -2.77694173e-02, -3.47223533e-02, -1.01451656e-01,
#         -3.78428173e-02, -6.47833828e-02,  0.00000000e+00,
#         -2.32633188e-02, -2.78874516e-01,  1.45074433e-01,
# ...

# %%
enr=ElasticNet(alpha=0.0001)
enr.fit(X_train,y_train)
enrpred=enr.predict(X_test)
print(enr.score(X_train,y_train))
enr.coef_
print(r2_score(y_test,enrpred))
# Out:
# 0.7863856872328617
# 0.802662808420016

# %%
#model Saving

import joblib

# %%
joblib.dump(enr,"Temperature_forecast.pkl")
# Out:
# ['Temperature_forecast.pkl']

# %%
#Loading the model
Model_Net=joblib.load('Temperature_forecast.pkl')
