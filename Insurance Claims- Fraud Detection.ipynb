# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Insurance.csv')

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 40)

# %% [markdown]
# Their are total 1000 rows and 40 columns.

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %% [markdown]
# Their are 17 columns of int data type,2 columns of float data type and 21 columns of object data type.

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.drop('_c39',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %% [markdown]
# Their are no  missing values in the dataset.

# %%
df.head(10)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
# 5                 256   39         104594       12-10-2006           OH
# 6                 137   34         413978       04-06-2000           IN
# 7                 165   37         429027       03-02-1990           IL
# 8                  27   33         485665       05-02-1997           IL
# 9                 212   42         636550       25-07-2011           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# ...

# %% [markdown]
# we will make policy number as our index column.

# %%
df.set_index("policy_number",inplace=True)

# %%
df
# Out:
#                months_as_customer  age policy_bind_date policy_state  \
# policy_number
# 521585                        328   48       17-10-2014           OH
# 342868                        228   42       27-06-2006           IN
# 687698                        134   29       06-09-2000           OH
# 227811                        256   41       25-05-1990           IL
# 367455                        228   44       06-06-2014           IL
# ...                           ...  ...              ...          ...
# 941851                          3   38       16-07-1991           OH
# 186934                        285   41       05-01-2014           IL
# 918516                        130   34       17-02-2003           OH
# 533940                        458   62       18-11-2011           IL
# 556080                        456   60       11-11-1996           OH
#
#               policy_csl  policy_deductable  policy_annual_premium  \
# policy_number
# ...

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_bind_date', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df.iloc[:,10:29]
# Out:
#               insured_education_level insured_occupation insured_hobbies  \
# policy_number
# 521585                             MD       craft-repair        sleeping
# 342868                             MD  machine-op-inspct         reading
# 687698                            PhD              sales     board-games
# 227811                            PhD       armed-forces     board-games
# 367455                      Associate              sales     board-games
# ...                               ...                ...             ...
# 941851                        Masters       craft-repair       paintball
# 186934                            PhD     prof-specialty        sleeping
# 918516                        Masters       armed-forces  bungie-jumping
# 533940                      Associate  handlers-cleaners    base-jumping
# 556080                      Associate              sales        kayaking
#
# ...

# %% [markdown]
# Checking the data present in other columns for more clarification.

# %%
df['collision_type'].unique()
# Out:
# array(['Side Collision', '?', 'Rear Collision', 'Front Collision'],
#       dtype=object)

# %%
df['insured_education_level'].unique()
# Out:
# array(['MD', 'PhD', 'Associate', 'Masters', 'High School', 'College',
#        'JD'], dtype=object)

# %%
df['insured_occupation'].unique()
# Out:
# array(['craft-repair', 'machine-op-inspct', 'sales', 'armed-forces',
#        'tech-support', 'prof-specialty', 'other-service',
#        'priv-house-serv', 'exec-managerial', 'protective-serv',
#        'transport-moving', 'handlers-cleaners', 'adm-clerical',
#        'farming-fishing'], dtype=object)

# %%
#We can drop 'insured_education_level' as we have data about their occupation.
df.drop('insured_education_level',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_bind_date', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_date', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df['policy_bind_date']
# Out:
# policy_number
# 521585    17-10-2014
# 342868    27-06-2006
# 687698    06-09-2000
# 227811    25-05-1990
# 367455    06-06-2014
#              ...
# 941851    16-07-1991
# 186934    05-01-2014
# 918516    17-02-2003
# 533940    18-11-2011
# 556080    11-11-1996
# Name: policy_bind_date, Length: 1000, dtype: object

# %%
df['incident_date']
# Out:
# policy_number
# 521585    25-01-2015
# 342868    21-01-2015
# 687698    22-02-2015
# 227811    10-01-2015
# 367455    17-02-2015
#              ...
# 941851    22-02-2015
# 186934    24-01-2015
# 918516    23-01-2015
# 533940    26-02-2015
# 556080    26-02-2015
# Name: incident_date, Length: 1000, dtype: object

# %%
df['auto_year']
# Out:
# policy_number
# 521585    2004
# 342868    2007
# 687698    2007
# 227811    2014
# 367455    2009
#           ...
# 941851    2006
# 186934    2015
# 918516    1996
# 533940    1998
# 556080    2007
# Name: auto_year, Length: 1000, dtype: int64

# %%
##Working on policy_bind_date and incident date

df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])

# %%
df["Year_pb"]=df['policy_bind_date'].dt.year
df["Month_pb"]=df['policy_bind_date'].dt.month
df['Day_pb']=df['policy_bind_date'].dt.day

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_bind_date', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_date', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', 'Year_pb', 'Month_pb',
#        'Day_pb'],
#       dtype='object')

# %%
df.drop('policy_bind_date',axis=1,inplace=True)

# %%
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
df["Year_inc"]=df['incident_date'].dt.year
df["Month_inc"]=df['incident_date'].dt.month
df['Day_inc']=df['incident_date'].dt.day

# %%
df.drop('incident_date',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', 'Year_pb', 'Month_pb',
#        'Day_pb', 'Year_inc', 'Month_inc', 'Day_inc'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 41)

# %%
df.head(10)
# Out:
#                months_as_customer  age policy_state policy_csl  \
# policy_number
# 521585                        328   48           OH    250/500
# 342868                        228   42           IN    250/500
# 687698                        134   29           OH    100/300
# 227811                        256   41           IL    250/500
# 367455                        228   44           IL   500/1000
# 104594                        256   39           OH    250/500
# 413978                        137   34           IN    250/500
# 429027                        165   37           IL    100/300
# 485665                         27   33           IL    100/300
# 636550                        212   42           IL    100/300
#
#                policy_deductable  policy_annual_premium  umbrella_limit  \
# policy_number
# 521585                      1000                1406.91               0
# 342868                      2000                1197.22         5000000
# ...

# %%
df['auto_make'].unique()
# Out:
# array(['Saab', 'Mercedes', 'Dodge', 'Chevrolet', 'Accura', 'Nissan',
#        'Audi', 'Toyota', 'Ford', 'Suburu', 'BMW', 'Jeep', 'Honda',
#        'Volkswagen'], dtype=object)

# %%
df['auto_model'].unique()
# Out:
# array(['92x', 'E400', 'RAM', 'Tahoe', 'RSX', '95', 'Pathfinder', 'A5',
#        'Camry', 'F150', 'A3', 'Highlander', 'Neon', 'MDX', 'Maxima',
#        'Legacy', 'TL', 'Impreza', 'Forrestor', 'Escape', 'Corolla',
#        '3 Series', 'C300', 'Wrangler', 'M5', 'X5', 'Civic', 'Passat',
#        'Silverado', 'CRV', '93', 'Accord', 'X6', 'Malibu', 'Fusion',
#        'Jetta', 'ML350', 'Ultima', 'Grand Cherokee'], dtype=object)

# %% [markdown]
# As we have Automobile companies in the dataset, we can drop the moel column.

# %%
df.drop('auto_model',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_year', 'fraud_reported', 'Year_pb', 'Month_pb', 'Day_pb',
#        'Year_inc', 'Month_inc', 'Day_inc'],
#       dtype='object')

# %%
df['policy_csl'].unique()
# Out:
# array(['250/500', '100/300', '500/1000'], dtype=object)

# %%
df['insured_hobbies']
# Out:
# policy_number
# 521585          sleeping
# 342868           reading
# 687698       board-games
# 227811       board-games
# 367455       board-games
#                ...
# 941851         paintball
# 186934          sleeping
# 918516    bungie-jumping
# 533940      base-jumping
# 556080          kayaking
# Name: insured_hobbies, Length: 1000, dtype: object

# %%
#We can drop this column

df.drop('insured_hobbies',axis=1,inplace=True)

# %%
df['insured_relationship'].unique()
# Out:
# array(['husband', 'other-relative', 'own-child', 'unmarried', 'wife',
#        'not-in-family'], dtype=object)

# %%
df['incident_type'].unique()
# Out:
# array(['Single Vehicle Collision', 'Vehicle Theft',
#        'Multi-vehicle Collision', 'Parked Car'], dtype=object)

# %%
df['collision_type'].unique()
# Out:
# array(['Side Collision', '?', 'Rear Collision', 'Front Collision'],
#       dtype=object)

# %%
df['incident_severity'].unique()
# Out:
# array(['Major Damage', 'Minor Damage', 'Total Loss', 'Trivial Damage'],
#       dtype=object)

# %%
df['authorities_contacted'].unique()
# Out:
# array(['Police', 'None', 'Fire', 'Other', 'Ambulance'], dtype=object)

# %%
df['incident_state'].unique()
# Out:
# array(['SC', 'VA', 'NY', 'OH', 'WV', 'NC', 'PA'], dtype=object)

# %%
df['incident_city'].unique()
# Out:
# array(['Columbus', 'Riverwood', 'Arlington', 'Springfield', 'Hillsdale',
#        'Northbend', 'Northbrook'], dtype=object)

# %%
df['incident_location'].unique()
# Out:
# array(['9935 4th Drive', '6608 MLK Hwy', '7121 Francis Lane',
#        '6956 Maple Drive', '3041 3rd Ave', '8973 Washington St',
#        '5846 Weaver Drive', '3525 3rd Hwy', '4872 Rock Ridge',
#        '3066 Francis Ave', '1558 1st Ridge', '5971 5th Hwy',
#        '6655 5th Drive', '6582 Elm Lane', '6851 3rd Drive',
#        '9573 Weaver Ave', '5074 3rd St', '4546 Tree St',
#        '3842 Solo Ridge', '8101 3rd Ridge', '5380 Pine St',
#        '8957 Weaver Drive', '2526 Embaracadero Ave', '5667 4th Drive',
#        '2502 Apache Hwy', '3418 Texas Lane', '2533 Elm St',
#        '3790 Andromedia Hwy', '3220 Rock Drive', '2100 Francis Drive',
#        '4687 5th Drive', '9038 2nd Lane', '6092 5th Ave',
#        '8353 Britain Ridge', '3540 Maple St', '3104 Sky Drive',
#        '4981 Weaver St', '6676 Tree Lane', '3930 Embaracadero St',
#        '3422 Flute St', '4862 Lincoln Hwy', '5719 2nd Lane',
#        '3221 Solo Ridge', '6660 MLK Drive', '1699 Oak Drive',
# ...

# %%
#we can drop this column as we have city name, state name and policy number with us.
df.drop('incident_location',axis=1,inplace=True)

# %%
df['incident_hour_of_the_day'].unique()
# Out:
# array([ 5,  8,  7, 20, 19,  0, 23, 21, 14, 22,  9, 12, 15,  6, 16,  4, 10,
#         1, 17,  3, 11, 13, 18,  2], dtype=int64)

# %%
df['number_of_vehicles_involved']
# Out:
# policy_number
# 521585    1
# 342868    1
# 687698    3
# 227811    1
# 367455    1
#          ..
# 941851    1
# 186934    1
# 918516    3
# 533940    1
# 556080    1
# Name: number_of_vehicles_involved, Length: 1000, dtype: int64

# %%
df['property_damage'].unique()
# Out:
# array(['YES', '?', 'NO'], dtype=object)

# %%
df['police_report_available'].unique()
# Out:
# array(['YES', '?', 'NO'], dtype=object)

# %% [markdown]
# Above, we analyze all the data present in the dataset.

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_occupation',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_year',
#        'fraud_reported', 'Year_pb', 'Month_pb', 'Day_pb', 'Year_inc',
#        'Month_inc', 'Day_inc'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='policy_state',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
df['policy_state'].unique()
# Out:
# array(['OH', 'IN', 'IL'], dtype=object)

# %% [markdown]
# Number of fraud cases are most in 'OH' state and least number of fraud cases are in 'IL' state.
#
#
# 'IL' is the state where number of no-fraudant is high and rate of no_fraudant cases is low in 'IN' state.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='insured_sex',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# For the Male category, in both the cases i.e., fraudant and no-Fraudant, is highest.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='insured_occupation',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Most of the fraudant cases are noticed for the occupation as'exec-managerial'.
#
#
# Most of the no-fraudant cases are noticed for the occupation as 'machine-op-inspect'.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='insured_relationship',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Fraudant case rate is high for the category sub-category of other_relative.
#
#
# no-feaudant case is high for sub-category of own_child.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='incident_type',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Rate of fraud cases is high for single vehicle collision.
#
# Rate of no-fraud cases is high for Multi-Vehicle-Collision.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='incident_severity',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Fraud cases are high when severity is a major_damage.
#
# Rate of no-fraud cases is high for severity as minor_Damage.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='number_of_vehicles_involved',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Frudant and no fraudant rate is high for the case where the number of vehicles involved is 1.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='property_damage',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Fraud cases are high where their is no record of property daamge(yes or  no).
#
# no fruadant rate is high for category of property damage as no.

# %%
df['bodily_injuries'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='auto_make',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Fraud cases are high for Mercedes company.
#
# No-fraudant cases are high for Nissan company.

# %%
sns.set_style('whitegrid')
sns.countplot(x='fraud_reported',hue='auto_year',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Highest number of fraud cases are there in the year 2007 and lowest in the year 1998.
#
# Highest number of no-fraud cases are there in the year 1999 and lowest in the year 2004.

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_occupation',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_year',
#        'fraud_reported', 'Year_pb', 'Month_pb', 'Day_pb', 'Year_inc',
#        'Month_inc', 'Day_inc'],
#       dtype='object')

# %%
plt.scatter(df['months_as_customer'],df['policy_annual_premium'],alpha=0.5,c=(0,0,0),edgecolor='r')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Their is mixed relationship between these two columns as linear and non linear.

# %%
plt.scatter(df['age'],df['policy_annual_premium'],alpha=0.5,c=(0,0,0),edgecolor='r')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# As in most of the thier is linear relationship between two columns.

# %%
plt.scatter(df['property_claim'],df['total_claim_amount'],alpha=0.5,c=(0,0,0),edgecolor='r')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Their is linear relationship in most of the cases for the two columns, as, amount for property claim is increasing,total amount claim also increasing and vice-versa.

# %%
 plt.scatter(df['injury_claim'],df['total_claim_amount'],alpha=0.5,c=(0,0,0),edgecolor='r')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# for most of the cases, linear relationship is found for the two columns.

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_occupation              object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# ...

# %%
plt.hist(df['age'])
plt.show()

# %% [markdown]
# In the dataset, more number of people are in the age_range (30 to 40).

# %%
plt.hist(df['policy_deductable'])
plt.show()

# %% [markdown]
# policy deductable amount is INR 1000-1100 for 350 users.
#
# Policy deductable amount is INR 400-600 for 330 users.
#
# Policy deductable amount is INR 1800-2000 for 320 users.

# %%
plt.hist(df['policy_state'])
plt.show()

# %% [markdown]
# 350 users are from 'OH' state.
#
# 340 usera are from 'IL' state.
#
# 310 users are from 'IN' state.

# %%
plt.hist(df['incident_city'])
plt.show()

# %% [markdown]
# Columbus - 148 users
#
# Riverwood - 138 users
#
# Arlington - 151 users
#
# Springfield - 158 users
#
# Hillsdale - 140 users
#
# Northbend - 143 users
#
# NorthBook - 122 users.

# %%
plt.hist(df['number_of_vehicles_involved'])
plt.show()

# %% [markdown]
# number of vehicles is 1 for 580 users, 2 for 20 users, 3 for 350 users and 4 for 50 users.

# %%
plt.hist(df['bodily_injuries'])
plt.show()

# %%
df['bodily_injuries'].value_counts()
# Out:
# 0    340
# 2    332
# 1    328
# Name: bodily_injuries, dtype: int64

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_deductable  \
# count         1000.000000  1000.000000        1000.000000
# mean           203.954000    38.948000        1136.000000
# std            115.113174     9.140287         611.864673
# min              0.000000    19.000000         500.000000
# 25%            115.750000    32.000000         500.000000
# 50%            199.500000    38.000000        1000.000000
# 75%            276.250000    44.000000        2000.000000
# max            479.000000    64.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# ...

# %%
df.shape
# Out:
# (1000, 38)

# %% [markdown]
# so, out of 38 columns, we got statistical summary of 23 columns. lets encode other columns for futher operations.

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_occupation              object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
list=['policy_state','policy_csl','insured_sex','insured_relationship','insured_occupation','incident_type','collision_type','incident_severity','authorities_contacted','incident_state','incident_city','property_damage','police_report_available','auto_make','fraud_reported']

# %%
for val in list:
    df[val]=le.fit_transform(df[val])

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                     int32
# policy_csl                       int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_occupation               int32
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authorities_contacted            int32
# incident_state                   int32
# incident_city                    int32
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                  int32
# bodily_injuries                  int64
# witnesses                        int64
# ...

# %% [markdown]
# We converted all the data into numeric format, we can proceed for further operations.

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['total_claim_amount'])
plt.show()

# %% [markdown]
# Highest density of total_claim_amount is in the range of INR 50,000 to 70,000.

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['injury_claim'])
plt.show()

# %% [markdown]
# Highest density injury claim amount is in the range between INR 5000 to 8000.

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['property_claim'])
plt.show()

# %% [markdown]
# Highest density property claim amount is in the range between INR 5000 to 7000.

# %%
plt.figure(figsize=[14,6])
sns.violinplot(df['vehicle_claim'])
plt.show()

# %% [markdown]
# Highest density for vehicle claim amount is in the range between INR 35000 to 57000.

# %% [markdown]
# Correlation

# %%
df['Year_inc']
# Out:
# policy_number
# 521585    2015
# 342868    2015
# 687698    2015
# 227811    2015
# 367455    2015
#           ...
# 941851    2015
# 186934    2015
# 918516    2015
# 533940    2015
# 556080    2015
# Name: Year_inc, Length: 1000, dtype: int64

# %% [markdown]
# dropping the column as all the values of all variables is same for the above column.

# %%
df.drop('Year_inc',axis=1,inplace=True)

# %% [markdown]
# Correlation

# %%
corr=df.corr()
corr
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922098     -0.000328
# age                                    0.922098  1.000000     -0.014533
# policy_state                          -0.000328 -0.014533      1.000000
# policy_csl                            -0.026819 -0.015185      0.001027
# policy_deductable                      0.026807  0.029188      0.010033
# policy_annual_premium                  0.005018  0.014404      0.012455
# umbrella_limit                         0.015498  0.018126     -0.029580
# insured_zip                            0.017895  0.025604      0.008777
# insured_sex                            0.060925  0.073337     -0.020481
# insured_occupation                     0.009814  0.017220     -0.031215
# insured_relationship                   0.069727  0.074832     -0.018506
# capital-gains                          0.006399 -0.007075      0.074551
# ...

# %%
plt.figure(figsize=[20,8])
sns.heatmap(corr,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We are unable to get proper insight from the heatmap. lets try further step.

# %%
corr_matrix=df.corr()
corr_matrix['fraud_reported'].sort_values(ascending=False)
# Out:
# fraud_reported                 1.000000
# vehicle_claim                  0.170049
# total_claim_amount             0.163651
# property_claim                 0.137835
# collision_type                 0.110130
# injury_claim                   0.090975
# Day_pb                         0.060643
# umbrella_limit                 0.058622
# number_of_vehicles_involved    0.051839
# witnesses                      0.049497
# bodily_injuries                0.033877
# insured_sex                    0.030873
# policy_state                   0.029432
# insured_relationship           0.021043
# months_as_customer             0.020544
# insured_zip                    0.019368
# policy_deductable              0.014817
# Month_inc                      0.014495
# age                            0.012143
# auto_year                      0.007928
# incident_hour_of_the_day       0.004316
# insured_occupation             0.001564
# Year_pb                       -0.000059
# ...

# %% [markdown]
# Highest correlation with 'fraud_reported'  - Vehicle_claim (0.17)
#
#
# Lowest correlation with 'fraud_reported'   - incident_severity(-0.4059)

# %% [markdown]
# Outliers_checking:-

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_occupation',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_year',
#        'fraud_reported', 'Year_pb', 'Month_pb', 'Day_pb', 'Month_inc',
#        'Day_inc'],
#       dtype='object')

# %%
df.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df['age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['policy_annual_premium'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['umbrella_limit'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# So there are outliers in ubrella_limit column.

# %% [markdown]
# for the above boxplots, their are ouliers in two columns but they are very near to whisker, we will proceed with them.

# %%
df.iloc[:,11:21].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# No outliers are there in above columns.

# %%
df.iloc[:,21:31].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# Their are some outliers in two columns but they are very near to whiskers, we will not remove them.

# %%
df.iloc[:,31:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# Outliers found but very near to whiskers, we will not remove them.

# %%
#divide the dataset into dependent and independent variables,

# %%
x=df.drop('fraud_reported',axis=1)
y=df['fraud_reported']

# %%
x
# Out:
#                months_as_customer  age  policy_state  policy_csl  \
# policy_number
# 521585                        328   48             2           1
# 342868                        228   42             1           1
# 687698                        134   29             2           0
# 227811                        256   41             0           1
# 367455                        228   44             0           2
# ...                           ...  ...           ...         ...
# 941851                          3   38             2           2
# 186934                        285   41             0           0
# 918516                        130   34             2           1
# 533940                        458   62             0           2
# 556080                        456   60             2           1
#
#                policy_deductable  policy_annual_premium  umbrella_limit  \
# policy_number
# 521585                      1000                1406.91               0
# ...

# %%
y
# Out:
# policy_number
# 521585    1
# 342868    1
# 687698    0
# 227811    1
# 367455    0
#          ..
# 941851    0
# 186934    0
# 918516    0
# 533940    0
# 556080    0
# Name: fraud_reported, Length: 1000, dtype: int32

# %% [markdown]
# skewness check

# %%
x.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_state                  -0.026177
# policy_csl                     0.088928
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# insured_sex                    0.148630
# insured_occupation            -0.058881
# insured_relationship           0.077488
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_type                  0.101507
# collision_type                -0.193345
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# property_damage                0.106418
# bodily_injuries                0.014777
# ...

# %% [markdown]
# As here most of the columns are Object data tytpe, we will not going to remove skewness for them.

# %% [markdown]
# Distribution of data

# %%
sns.distplot(df['months_as_customer'])
# Out:
# <AxesSubplot:xlabel='months_as_customer', ylabel='Density'>

# %% [markdown]
# Data is normally distributed.

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# Normal distribution is there.

# %%
sns.distplot(df['policy_deductable'])
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='Density'>

# %% [markdown]
# Data is normally distributed.

# %%
sns.distplot(df['policy_annual_premium'])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='Density'>

# %% [markdown]
# Data is normally distributed.

# %%
sns.distplot(df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Density'>

# %% [markdown]
# Data is normally distributed.

# %%
sns.distplot(df['injury_claim'])
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='Density'>

# %%
sns.distplot(df['property_claim'])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='Density'>

# %% [markdown]
# So, in most of the columns, data is normally diostributed, we will proceed for further operations.

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X=sc.fit_transform(x)
X=pd.DataFrame(X,columns=x.columns)

# %%
X
# Out:
#      months_as_customer       age  policy_state  policy_csl  \
# 0              1.078140  0.990836      1.187173    0.060937
# 1              0.208995  0.334073     -0.016856    0.060937
# 2             -0.608002 -1.088913      1.187173   -1.182668
# 3              0.452355  0.224613     -1.220886    0.060937
# 4              0.208995  0.552994     -1.220886    1.304542
# ..                  ...       ...           ...         ...
# 995           -1.746582 -0.103769      1.187173    1.304542
# 996            0.704407  0.224613     -1.220886   -1.182668
# 997           -0.642767 -0.541611      1.187173    0.060937
# 998            2.208028  2.523284     -1.220886    1.304542
# 999            2.190645  2.304363      1.187173    0.060937
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0            -0.222383               0.616705       -0.479476    -0.489529
# 1             1.412784              -0.242521        1.697980    -0.461008
# ...

# %% [markdown]
# Data is scaled.

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Class imbalance is there, which might affect our accuracy, lets resolve this problem.

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=42)

# %%
X_train.shape
# Out:
# (700, 36)

# %%
X_test.shape
# Out:
# (300, 36)

# %%
y_train.shape
# Out:
# (700,)

# %%
y_test.shape
# Out:
# (300,)

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE(random_state=42)

X_res, y_res = sm.fit_resample(X,y)

# %%
X_res.shape
# Out:
# (1506, 36)

# %%
y_res.shape
# Out:
# (1506,)

# %%
from collections import Counter

# %%
print('original dataset shape{}'.format(Counter(y)))
print('Resampled dataset shape{}'.format(Counter(y_res)))
# Out:
# original dataset shapeCounter({0: 753, 1: 247})
# Resampled dataset shapeCounter({1: 753, 0: 753})

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
##Finding the best random state

maxAccu=0
maxRs=0
for i in range(1,200):
    X_res_train,X_res_test,y_res_train,y_res_test=train_test_split(X_res,y_res,test_size=.30,random_state=i)
    LR=LogisticRegression()
    LR.fit(X_res_train,y_res_train)
    pred=LR.predict(X_res_test)
    acc=accuracy_score(y_res_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
        
print("Best accuracy is", maxAccu,"on Random state", maxRs)
# Out:
# Best accuracy is 0.7743362831858407 on Random state 156

# %% [markdown]
# Creating new train test split with random state 156.

# %%
X_res_train,X_res_test,y_res_train,y_res_test=train_test_split(X_res,y_res,test_size=.30,random_state=156)

# %%
LR=LogisticRegression()
LR.fit(X_res_train,y_res_train)
pred=LR.predict(X_res_test)
print(accuracy_score(y_res_test,pred))
print(confusion_matrix(y_res_test,pred))
print(classification_report(y_res_test,pred))
# Out:
# 0.7743362831858407
# [[164  54]
#  [ 48 186]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       218
#            1       0.78      0.79      0.78       234
#
#     accuracy                           0.77       452
#    macro avg       0.77      0.77      0.77       452
# weighted avg       0.77      0.77      0.77       452

# %%
dt=DecisionTreeClassifier()
dt.fit(X_res_train,y_res_train)
pred=dt.predict(X_res_test)
print(accuracy_score(y_res_test,pred))
print(confusion_matrix(y_res_test,pred))
print(classification_report(y_res_test,pred))
# Out:
# 0.7765486725663717
# [[165  53]
#  [ 48 186]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77       218
#            1       0.78      0.79      0.79       234
#
#     accuracy                           0.78       452
#    macro avg       0.78      0.78      0.78       452
# weighted avg       0.78      0.78      0.78       452

# %%
sv=SVC()
sv.fit(X_res_train,y_res_train)
pred=sv.predict(X_res_test)
print(accuracy_score(y_res_test,pred))
print(confusion_matrix(y_res_test,pred))
print(classification_report(y_res_test,pred))
# Out:
# 0.8407079646017699
# [[182  36]
#  [ 36 198]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       218
#            1       0.85      0.85      0.85       234
#
#     accuracy                           0.84       452
#    macro avg       0.84      0.84      0.84       452
# weighted avg       0.84      0.84      0.84       452

# %%
gb=GaussianNB()
gb.fit(X_res_train,y_res_train)
pred=gb.predict(X_res_test)
print(accuracy_score(y_res_test,pred))
print(confusion_matrix(y_res_test,pred))
print(classification_report(y_res_test,pred))
# Out:
# 0.7234513274336283
# [[122  96]
#  [ 29 205]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.56      0.66       218
#            1       0.68      0.88      0.77       234
#
#     accuracy                           0.72       452
#    macro avg       0.74      0.72      0.71       452
# weighted avg       0.74      0.72      0.72       452

# %%
rf=RandomForestClassifier()
rf.fit(X_res_train,y_res_train)
pred=rf.predict(X_res_test)
print(accuracy_score(y_res_test,pred))
print(confusion_matrix(y_res_test,pred))
print(classification_report(y_res_test,pred))
# Out:
# 0.8495575221238938
# [[188  30]
#  [ 38 196]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       218
#            1       0.87      0.84      0.85       234
#
#     accuracy                           0.85       452
#    macro avg       0.85      0.85      0.85       452
# weighted avg       0.85      0.85      0.85       452

# %% [markdown]
# We got accuracies for different models, it might be due to overfitting, we will check cross val score.

# %%
#Cross_Validation

scr=cross_val_score(LR,X_res,y_res,cv=5)
print(scr.mean())
# Out:
# 0.7297463202129767

# %%
scr=cross_val_score(dt,X_res,y_res,cv=5)
print(scr.mean())
# Out:
# 0.778953158346351

# %%
scr=cross_val_score(rf,X_res,y_res,cv=5)
print(scr.mean())
# Out:
# 0.875270071065543

# %%
scr=cross_val_score(gb,X_res,y_res,cv=5)
print(scr.mean())
# Out:
# 0.703865701524719

# %%
scr=cross_val_score(sv,X_res,y_res,cv=5)
print(scr.mean())
# Out:
# 0.8685705485027831

# %% [markdown]
# As the difference is less for SVC, (ACCU and Cross val), we will do Hyperparameter tuning for it.

# %%
parameters={'C':[0.1,1,10,100,1000],
           'kernel':['poly','rbf','sigmoid']}

# %%
GCV_svc=GridSearchCV(SVC(),parameters,cv=5)
GCV_svc.fit(X_res_train,y_res_train)
GCV_svc.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
SVC_M=SVC(C=10,kernel='rbf')
SVC_M.fit(X_res_train,y_res_train)
pred=SVC_M.predict(X_res_test)
print(accuracy_score(y_res_test,pred)*100)
# Out:
# 87.38938053097345

# %% [markdown]
# Final accuracy of the model is 87.38%

# %%
#model Saving
import joblib

# %%
joblib.dump(SVC_M,"Insurance_Claim.pkl")
# Out:
# ['Insurance_Claim.pkl']

# %%
#model loading

# %%
Final_Model=joblib.load("Insurance_claim.pkl")
